# %%
import pandas as pd

# %%
beer_data = pd.read_csv(f"./data/beers_metadata.csv")

# %%
from DummyModel import DummyModel

# %%
model = DummyModel()

# %%
pred = model.predict(10)

# %%
x=[1,2,3,4]

# %%
beer = beer_data[beer_data.beer_id.isin(x)]

# %%
# Out:
#                          name                 brewery  rating  \
# 2158            Piwo Miodowe               BROWAR EDI     1.0
# 5724      San Escobeer Ananas             DOCTOR BREW     1.0
# 3122                   Blonde         BROWAR WHYDUCK?     1.0
# 2159            Piwo Imbirowe              BROWAR EDI     1.0
# 2154         Wschowskie Jasne              BROWAR EDI     1.0
# 8292    Swojskie Bezglutenowe  BROWAR POŁCZYN - ZDRÓJ     1.0
# 7540       Lubuskie & Tequila          BROWAR WITNICA     1.0
# 3853  Smaki Browarki Sielskie         BROWAR BROWARKA     1.0
# 6427               Mądry Hans          BROWAR BEDNARY     1.0
# 2257         Połczyńskie Bock        MINIBROWAR KOWAL     1.0
#
#                                               logo_link  beer_id   blg  alc  \
# 2158  https://www.polskikraft.pl/img/photos/14779971...     2174    15  5.6
# 5724  https://www.polskikraft.pl/img/photos/14435595...     5753     -  1.5
# ...

# %%
ratings = pd.read_csv(f"./data/ratings.csv")

# %%
ratings.groupby(['beer_id'],as_index=False).count().sort_values(by=["comment"]).beer_id.head(10)
# Out:
# array([4827, 6333, 6337, 2045, 6344, 6350, 2038, 6360, 6361, 6365],
#       dtype=int64)
